# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # IMPORTING THE FILE IN NOTEBOOK

# %%
world=pd.read_csv(r'C:\Users\aksha\Downloads\world bank.csv')

# %% [markdown]
# # ITERATING THE FILE

# %%
world[:45]
# Out:
#                       Country Name Region Code Country Code  \
# 0                            Aruba          MA          ABW
# 1                          Andorra          EU          AND
# 2                      Afghanistan          ME          AFG
# 3                           Angola          AF          AGO
# 4                          Albania          EU          ALB
# 5                       Arab World         NaN          ARB
# 6             United Arab Emirates          ME          ARE
# 7                        Argentina          SA          ARG
# 8                          Armenia          RU          ARM
# 9                   American Samoa          PA          ASM
# 10             Antigua and Barbuda          MA          ATG
# 11                       Australia          AU          AUS
# 12                         Austria          EU          AUT
# 13                      Azerbaijan          RU          AZE
# 14                         Burundi          AF          BDI
# ...

# %%
world[-45:]
# Out:
#                                           Country Name Region Code  \
# 219                                           Slovenia          EU
# 220                                             Sweden          EU
# 221                                          Swaziland          AF
# 222                          Sint Maarten (Dutch part)          MA
# 223                                         Seychelles         NaN
# 224                               Syrian Arab Republic          ME
# 225                           Turks and Caicos Islands          MA
# 226                                               Chad          AF
# 227         East Asia & Pacific (IDA & IBRD countries)         NaN
# 228       Europe & Central Asia (IDA & IBRD countries)         NaN
# 229                                               Togo          AF
# 230                                           Thailand          SE
# 231                                         Tajikistan          ME
# ...

# %% [markdown]
# # ASSESING THE DATA FOR DETAILS

# %%
world.describe()
# Out:
#        GDP, PPP (current international $)  Population, total  \
# count                        2.140000e+02       2.620000e+02
# mean                         4.758337e+12       2.970610e+08
# std                          1.370366e+13       9.376648e+08
# min                          2.089545e+08       9.916000e+03
# 25%                          3.015109e+10       1.464251e+06
# 50%                          1.679590e+11       1.009667e+07
# 75%                          1.584582e+12       5.469198e+07
# max                          1.136540e+14       7.346633e+09
#
#        Population CGR 1960-2015  Internet users (per 100 people)  \
# count                258.000000                       248.000000
# mean                   0.018255                        47.556571
# std                    0.011218                        27.691717
# min                   -0.001666                         1.083733
# 25%                    0.009471                        21.932051
# ...

# %%
world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 11 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country Name                                                  264 non-null    object
#  1   Region Code                                                   210 non-null    object
#  2   Country Code                                                  264 non-null    object
#  3   GDP, PPP (current international $)                            214 non-null    float64
#  4   Population, total                                             262 non-null    float64
#  5   Population CGR 1960-2015                                      258 non-null    float64
#  6   Internet users (per 100 people)                               248 non-null    float64
# ...

# %%
world.shape
# Out:
# (264, 11)

# %%
world.nunique()
# Out:
# Country Name                                                    264
# Region Code                                                      11
# Country Code                                                    264
# GDP, PPP (current international $)                              212
# Population, total                                               260
# Population CGR 1960-2015                                        256
# Internet users (per 100 people)                                 241
# Popltn Largest City % of Urban Pop                              188
# 2014 Life expectancy at birth, total (years)                    243
# Literacy rate, adult female (% of females ages 15 and above)    156
# Exports of goods and services (% of GDP)                        177
# dtype: int64

# %% [markdown]
# # CHECKING FOR NULL VALUES

# %%
world.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                      54
# Country Code                                                      0
# GDP, PPP (current international $)                               50
# Population, total                                                 2
# Population CGR 1960-2015                                          6
# Internet users (per 100 people)                                  16
# Popltn Largest City % of Urban Pop                               72
# 2014 Life expectancy at birth, total (years)                     19
# Literacy rate, adult female (% of females ages 15 and above)    108
# Exports of goods and services (% of GDP)                         84
# dtype: int64

# %%
world.notnull().sum()
# Out:
# Country Name                                                    264
# Region Code                                                     210
# Country Code                                                    264
# GDP, PPP (current international $)                              214
# Population, total                                               262
# Population CGR 1960-2015                                        258
# Internet users (per 100 people)                                 248
# Popltn Largest City % of Urban Pop                              192
# 2014 Life expectancy at birth, total (years)                    245
# Literacy rate, adult female (% of females ages 15 and above)    156
# Exports of goods and services (% of GDP)                        180
# dtype: int64

# %%
world.columns
# Out:
# Index(['Country Name', 'Region Code', 'Country Code',
#        'GDP, PPP (current international $)', 'Population, total',
#        'Population CGR 1960-2015', 'Internet users (per 100 people)',
#        'Popltn Largest City % of Urban Pop',
#        '2014 Life expectancy at birth, total (years)',
#        'Literacy rate, adult female (% of females ages 15 and above)',
#        'Exports of goods and services (% of GDP)'],
#       dtype='object')

# %% [markdown]
# # FILL ALL THE NULL CELLS WITH '0'

# %%
world2 = world.fillna({'Region Code':0})

# %%
world2.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                       0
# Country Code                                                      0
# GDP, PPP (current international $)                               50
# Population, total                                                 2
# Population CGR 1960-2015                                          6
# Internet users (per 100 people)                                  16
# Popltn Largest City % of Urban Pop                               72
# 2014 Life expectancy at birth, total (years)                     19
# Literacy rate, adult female (% of females ages 15 and above)    108
# Exports of goods and services (% of GDP)                         84
# dtype: int64

# %%
world3 = world2.fillna({'GDP, PPP (current international $)':0})

# %%
world3.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                       0
# Country Code                                                      0
# GDP, PPP (current international $)                                0
# Population, total                                                 2
# Population CGR 1960-2015                                          6
# Internet users (per 100 people)                                  16
# Popltn Largest City % of Urban Pop                               72
# 2014 Life expectancy at birth, total (years)                     19
# Literacy rate, adult female (% of females ages 15 and above)    108
# Exports of goods and services (% of GDP)                         84
# dtype: int64

# %%
world4 = world3.fillna({'Population, total':0})

# %%
world4.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                       0
# Country Code                                                      0
# GDP, PPP (current international $)                                0
# Population, total                                                 0
# Population CGR 1960-2015                                          6
# Internet users (per 100 people)                                  16
# Popltn Largest City % of Urban Pop                               72
# 2014 Life expectancy at birth, total (years)                     19
# Literacy rate, adult female (% of females ages 15 and above)    108
# Exports of goods and services (% of GDP)                         84
# dtype: int64

# %%
world5 = world4.fillna({'Population CGR 1960-2015':0})

# %%
world5.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                       0
# Country Code                                                      0
# GDP, PPP (current international $)                                0
# Population, total                                                 0
# Population CGR 1960-2015                                          0
# Internet users (per 100 people)                                  16
# Popltn Largest City % of Urban Pop                               72
# 2014 Life expectancy at birth, total (years)                     19
# Literacy rate, adult female (% of females ages 15 and above)    108
# Exports of goods and services (% of GDP)                         84
# dtype: int64

# %%
world6 = world5.fillna({'Internet users (per 100 people)':0})

# %%
world6.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                       0
# Country Code                                                      0
# GDP, PPP (current international $)                                0
# Population, total                                                 0
# Population CGR 1960-2015                                          0
# Internet users (per 100 people)                                   0
# Popltn Largest City % of Urban Pop                               72
# 2014 Life expectancy at birth, total (years)                     19
# Literacy rate, adult female (% of females ages 15 and above)    108
# Exports of goods and services (% of GDP)                         84
# dtype: int64

# %%
world7 = world6.fillna({'Popltn Largest City % of Urban Pop':0})

# %%
world7.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                       0
# Country Code                                                      0
# GDP, PPP (current international $)                                0
# Population, total                                                 0
# Population CGR 1960-2015                                          0
# Internet users (per 100 people)                                   0
# Popltn Largest City % of Urban Pop                                0
# 2014 Life expectancy at birth, total (years)                     19
# Literacy rate, adult female (% of females ages 15 and above)    108
# Exports of goods and services (% of GDP)                         84
# dtype: int64

# %%
world8 = world7.fillna({'2014 Life expectancy at birth, total (years)':0})

# %%
world8.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                       0
# Country Code                                                      0
# GDP, PPP (current international $)                                0
# Population, total                                                 0
# Population CGR 1960-2015                                          0
# Internet users (per 100 people)                                   0
# Popltn Largest City % of Urban Pop                                0
# 2014 Life expectancy at birth, total (years)                      0
# Literacy rate, adult female (% of females ages 15 and above)    108
# Exports of goods and services (% of GDP)                         84
# dtype: int64

# %%
world9 = world8.fillna({'Literacy rate, adult female (% of females ages 15 and above)':0})

# %%
world9.isnull().sum()
# Out:
# Country Name                                                     0
# Region Code                                                      0
# Country Code                                                     0
# GDP, PPP (current international $)                               0
# Population, total                                                0
# Population CGR 1960-2015                                         0
# Internet users (per 100 people)                                  0
# Popltn Largest City % of Urban Pop                               0
# 2014 Life expectancy at birth, total (years)                     0
# Literacy rate, adult female (% of females ages 15 and above)     0
# Exports of goods and services (% of GDP)                        84
# dtype: int64

# %%
world10 = world9.fillna({'Exports of goods and services (% of GDP)':0})

# %%
world10.isnull().sum()
# Out:
# Country Name                                                    0
# Region Code                                                     0
# Country Code                                                    0
# GDP, PPP (current international $)                              0
# Population, total                                               0
# Population CGR 1960-2015                                        0
# Internet users (per 100 people)                                 0
# Popltn Largest City % of Urban Pop                              0
# 2014 Life expectancy at birth, total (years)                    0
# Literacy rate, adult female (% of females ages 15 and above)    0
# Exports of goods and services (% of GDP)                        0
# dtype: int64

# %%
world10[:45]
# Out:
#                       Country Name Region Code Country Code  \
# 0                            Aruba          MA          ABW
# 1                          Andorra          EU          AND
# 2                      Afghanistan          ME          AFG
# 3                           Angola          AF          AGO
# 4                          Albania          EU          ALB
# 5                       Arab World           0          ARB
# 6             United Arab Emirates          ME          ARE
# 7                        Argentina          SA          ARG
# 8                          Armenia          RU          ARM
# 9                   American Samoa          PA          ASM
# 10             Antigua and Barbuda          MA          ATG
# 11                       Australia          AU          AUS
# 12                         Austria          EU          AUT
# 13                      Azerbaijan          RU          AZE
# 14                         Burundi          AF          BDI
# ...

# %%
world[-45:]
# Out:
#                                           Country Name Region Code  \
# 219                                           Slovenia          EU
# 220                                             Sweden          EU
# 221                                          Swaziland          AF
# 222                          Sint Maarten (Dutch part)          MA
# 223                                         Seychelles         NaN
# 224                               Syrian Arab Republic          ME
# 225                           Turks and Caicos Islands          MA
# 226                                               Chad          AF
# 227         East Asia & Pacific (IDA & IBRD countries)         NaN
# 228       Europe & Central Asia (IDA & IBRD countries)         NaN
# 229                                               Togo          AF
# 230                                           Thailand          SE
# 231                                         Tajikistan          ME
# ...

# %% [markdown]
# # VISUALISING THE DATATSET

# %% [markdown]
# # A)PAIRPLOT

# %%
sns.pairplot(world10)

# %% [markdown]
# # B)HEATMAP

# %%
sns.heatmap(world10.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # C)COUNTPLOT

# %%
sns.set_style('whitegrid')
sns.countplot(x="Region Code", data=world10,palette = "Set2");

# %% [markdown]
# # D)JOINTPLOT

# %%
sns.jointplot(data=world10, x="Population, total", y="GDP, PPP (current international $)")

# %%
sns.jointplot(data=world10, x="Population CGR 1960-2015", y="Popltn Largest City % of Urban Pop")

# %% [markdown]
# # E)KDE PLOT

# %%
sns.kdeplot(data=world10, x="Exports of goods and services (% of GDP)")
# Out:
# <AxesSubplot:xlabel='Exports of goods and services (% of GDP)', ylabel='Density'>

# %%
sns.kdeplot(data=world10, x="Population CGR 1960-2015")
# Out:
# <AxesSubplot:xlabel='Population CGR 1960-2015', ylabel='Density'>

# %%
sns.kdeplot(data=world10, x="Literacy rate, adult female (% of females ages 15 and above)")
# Out:
# <AxesSubplot:xlabel='Literacy rate, adult female (% of females ages 15 and above)', ylabel='Density'>

# %%
sns.kdeplot(data=world10, x="2014 Life expectancy at birth, total (years)")
# Out:
# <AxesSubplot:xlabel='2014 Life expectancy at birth, total (years)', ylabel='Density'>

# %% [markdown]
# # F)PIECHART

# %%
y = ([54, 48, 47, 30, 26, 16, 12, 11, 7, 7, 4, 2])
Region_Code= ["0", "AF", "EU", "MA", "ME", "PA", "SA", "SE", "SS", "EA", "RU", "AU"]

plt.pie(y, labels =Region_Code,radius=2.9,autopct='%0.1f%%')
plt.legend()
plt.show()

# %% [markdown]
# # G)SCATTERPLOT

# %%
sns.scatterplot(data=world10, x="Population CGR 1960-2015", y="Internet users (per 100 people)", hue="Region Code")
# Out:
# <AxesSubplot:xlabel='Population CGR 1960-2015', ylabel='Internet users (per 100 people)'>

# %%
sns.scatterplot(data=world10, x="Population CGR 1960-2015", y="Literacy rate, adult female (% of females ages 15 and above)", hue="Region Code")
# Out:
# <AxesSubplot:xlabel='Population CGR 1960-2015', ylabel='Literacy rate, adult female (% of females ages 15 and above)'>
